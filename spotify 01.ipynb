# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(r'C:\Users\arinc\OneDrive\Desktop\final_tracks.csv')
df2 = pd.read_csv(r"C:\Users\arinc\OneDrive\Desktop\main_dataset.csv")

# %%
df1.head().T
# Out:
#                                                                0  \
# Unnamed: 0                                                     0
# name               DON'T LOOK DOWN (feat. Lizzy Land) - Acoustic
# artists_names                         ['San Holo', 'Lizzy Land']
# track_uri                   spotify:track:0wHwGDYc8nltuYykhZRKln
# popularity                                                    44
# album_type                                                single
# is_playable                                                 True
# release_date                                          2023-02-24
# artists_uris   ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# playlist_uris        ['spotify:playlist:1JvcIFP3w2EqpkZFo8LPSg']
#
#                                                                1  \
# Unnamed: 0                                                     1
# name                          DON'T LOOK DOWN (feat. Lizzy Land)
# artists_names                         ['San Holo', 'Lizzy Land']
# track_uri                   spotify:track:5rIpzFDp0sYDCQytYDG96W
# popularity                                                    55
# album_type                                                single
# is_playable                                                 True
# release_date                                          2023-01-27
# artists_uris   ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# playlist_uris  ['spotify:playlist:37i9dQZF1DWX8l0PIEOYVj', 's...
#
#                                                          2  \
# Unnamed: 0                                               2
# name                             All The Highs - VIP Outro
# artists_names                                 ['San Holo']
# track_uri             spotify:track:0MijKSpjO4RJ3p6aCHJfKh
# popularity                                              25
# album_type                                          single
# is_playable                                           True
# release_date                                    2022-12-16
# artists_uris     ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo']
# playlist_uris  ['spotify:playlist:1JvcIFP3w2EqpkZFo8LPSg']
#
#                                                          3  \
# Unnamed: 0                                               3
# name                                All The Highs - Slowed
# artists_names                                 ['San Holo']
# track_uri             spotify:track:5aiGF3goUtkx6c5vObwEY9
# popularity                                              34
# album_type                                          single
# is_playable                                           True
# release_date                                    2022-12-16
# artists_uris     ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo']
# playlist_uris  ['spotify:playlist:1JvcIFP3w2EqpkZFo8LPSg']
#
#                                                                4
# Unnamed: 0                                                     4
# name                                 All The Highs - IMANU Remix
# artists_names                              ['San Holo', 'IMANU']
# track_uri                   spotify:track:3BELIEnDdXEpgMuih6XsMQ
# popularity                                                    39
# album_type                                                single
# is_playable                                                 True
# release_date                                          2022-12-09
# artists_uris   ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# playlist_uris        ['spotify:playlist:1JvcIFP3w2EqpkZFo8LPSg']

# %%
df1.drop(columns = ['playlist_uris', 'playlist_uris', 'track_uri', 'Unnamed: 0'], inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277999 entries, 0 to 277998
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   name           277984 non-null  object
#  1   artists_names  277999 non-null  object
#  2   popularity     277999 non-null  int64
#  3   album_type     277999 non-null  object
#  4   is_playable    277999 non-null  bool
#  5   release_date   277999 non-null  object
#  6   artists_uris   277999 non-null  object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 13.0+ MB

# %%
df1.head()
# Out:
#                                             name               artists_names  \
# 0  DON'T LOOK DOWN (feat. Lizzy Land) - Acoustic  ['San Holo', 'Lizzy Land']
# 1             DON'T LOOK DOWN (feat. Lizzy Land)  ['San Holo', 'Lizzy Land']
# 2                      All The Highs - VIP Outro                ['San Holo']
# 3                         All The Highs - Slowed                ['San Holo']
# 4                    All The Highs - IMANU Remix       ['San Holo', 'IMANU']
#
#    popularity album_type  is_playable release_date  \
# 0          44     single         True   2023-02-24
# 1          55     single         True   2023-01-27
# 2          25     single         True   2022-12-16
# 3          34     single         True   2022-12-16
# 4          39     single         True   2022-12-09
#
#                                         artists_uris
# 0  ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# 1  ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# 2          ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo']
# 3          ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo']
# 4  ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...

# %%
df1.dropna
# Out:
# <bound method DataFrame.dropna of                                                  name  \
# 0       DON'T LOOK DOWN (feat. Lizzy Land) - Acoustic
# 1                  DON'T LOOK DOWN (feat. Lizzy Land)
# 2                           All The Highs - VIP Outro
# 3                              All The Highs - Slowed
# 4                         All The Highs - IMANU Remix
# ...                                               ...
# 277994                                           Corn
# 277995                            everything i wanted
# 277996                                  April Showers
# 277997                                    Warm Breeze
# 277998                                  Sunset Breeze
#
#                                             artists_names  popularity  \
# 0                              ['San Holo', 'Lizzy Land']          44
# 1                              ['San Holo', 'Lizzy Land']          55
# 2                                            ['San Holo']          25
# 3                                            ['San Holo']          34
# 4                                   ['San Holo', 'IMANU']          39
# ...                                                   ...         ...
# 277994        ['Lofi Fruits Music', 'Chill Fruits Music']          50
# 277995  ['Lofi Fruits Music', 'Avocuddle', 'Chill Frui...           0
# 277996        ['Lofi Fruits Music', 'Chill Fruits Music']          49
# 277997        ['Lofi Fruits Music', 'Chill Fruits Music']          51
# 277998        ['Lofi Fruits Music', 'Chill Fruits Music']          47
#
#        album_type  is_playable release_date  \
# 0          single         True   2023-02-24
# 1          single         True   2023-01-27
# 2          single         True   2022-12-16
# 3          single         True   2022-12-16
# 4          single         True   2022-12-09
# ...           ...          ...          ...
# 277994      album         True   2021-09-24
# 277995      album         True   2021-04-09
# 277996      album         True   2021-07-09
# 277997      album         True   2021-09-24
# 277998      album         True   2021-07-09
#
#                                              artists_uris
# 0       ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# 1       ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# 2               ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo']
# 3               ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo']
# 4       ['spotify:artist:0jNDKefhfSbLR9sFvcPLHo', 'spo...
# ...                                                   ...
# 277994  ['spotify:artist:1dABGukgZ8XKKOdd2rVSHM', 'spo...
# 277995  ['spotify:artist:1dABGukgZ8XKKOdd2rVSHM', 'spo...
# 277996  ['spotify:artist:1dABGukgZ8XKKOdd2rVSHM', 'spo...
# 277997  ['spotify:artist:1dABGukgZ8XKKOdd2rVSHM', 'spo...
# 277998  ['spotify:artist:1dABGukgZ8XKKOdd2rVSHM', 'spo...
#
# [277999 rows x 7 columns]>

# %%
df1 = pd.DataFrame(df1)

# %%
df1.isnull().sum()
# Out:
# name             15
# artists_names     0
# popularity        0
# album_type        0
# is_playable       0
# release_date      0
# artists_uris      0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.shape
# Out:
# (277984, 7)

# %%
df2.isnull().sum()
# Out:
# track_uri                0
# name                    15
# artists_names            0
# popularity               0
# album_type               0
# is_playable              0
# release_date             0
# artists_uris             0
# playlist_uris            0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# analysis_url             0
# duration_ms              0
# time_signature           0
# artists_popularities     0
# artists_genres           0
# artists_followers        0
# dtype: int64

# %%
df2.dropna()
# Out:
#                                    track_uri                             name  \
# 0       spotify:track:3v6sBj3swihU8pXQQHhDZo            Way Up (feat. Ava Re)
# 1       spotify:track:7KCWmFdw0TzoJbKtqRRzJO      Fantasy - Felix Jaehn Remix
# 2       spotify:track:2CY92qejUrhyPUASawNVRr                           Try Me
# 3       spotify:track:11BPfwVbB7vok7KfjBeW4k  Walk on by (Sound Remedy Remix)
# 4       spotify:track:3yUJKPsjvThlcQWTS9ttYx                     Pretty Wings
# ...                                      ...                              ...
# 277933  spotify:track:6wLr2oR8eqUG5Beleh2Crm               You Can Call Me Al
# 277934  spotify:track:5mYtpXrZZ1bbGJYDGC8I0Y                  99 Red Balloons
# 277935  spotify:track:7FwBtcecmlpc1sLySPXeGE              Dancing In the Dark
# 277936  spotify:track:2olVm1lHicpveMAo4AUDRB                The Power Of Love
# 277937  spotify:track:2VNfJpwdEQBLyXajaa6LWT           Burning Down the House
#
#                           artists_names  popularity   album_type  is_playable  \
# 0                           ['Floduxe']           0       single         True
# 1         ['Alina Baraz', 'Galimatias']          33        album         True
# 2                          ['DeJ Loaf']          52       single         True
# 3                             ['Noosa']           0       single         True
# 4       ['Zak Waters', 'Pretty Sister']           0       single         True
# ...                                 ...         ...          ...          ...
# 277933                   ['Paul Simon']          54  compilation         True
# 277934                         ['Nena']           0        album         True
# 277935            ['Bruce Springsteen']          77        album         True
# 277936        ['Huey Lewis & The News']          74  compilation         True
# 277937                ['Talking Heads']          64       single         True
#
#        release_date                                       artists_uris  \
# 0        2015-11-20          ['spotify:artist:4B7SI5PsnEgeMQd6gSIrbn']
# 1        2015-09-04  ['spotify:artist:6hfwwpXqZPRC9CsKI7qtv1', 'spo...
# 2        2014-10-15          ['spotify:artist:7kFfY4UjNdNyaeUgLIEbIF']
# 3        2014-07-10          ['spotify:artist:2F8tffsSfw1767WgjtAHBW']
# 4        2014-06-17  ['spotify:artist:0B8XBGloduGCBtRK8nm2YF', 'spo...
# ...             ...                                                ...
# 277933         2007          ['spotify:artist:2CvCyf1gEVhI0mX6aFXmVI']
# 277934   1984-08-21          ['spotify:artist:6Tz0QRoe083BcOo2YbG9lV']
# 277935   1984-06-04          ['spotify:artist:3eqjTLE0HfPfh78zjh6TqT']
# 277936   2006-01-01          ['spotify:artist:7A9yZMTrFZcgEWAX2kBfK6']
# 277937   1983-06-01          ['spotify:artist:2x9SpqnPi8rlE9pjHBwmSC']
#
#                                             playlist_uris  danceability  ...  \
# 0             ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']         0.611  ...
# 1             ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']         0.638  ...
# 2             ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']         0.560  ...
# 3             ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']         0.525  ...
# 4             ['spotify:playlist:5JJZvA3VR9RZ5XIr0reWiM']         0.367  ...
# ...                                                   ...           ...  ...
# 277933  ['spotify:playlist:1sWZkuhafsy05P3mpCWwlH', 's...         0.777  ...
# 277934  ['spotify:playlist:6KaF2jOKBgirsyeASOXwxT', 's...         0.543  ...
# 277935  ['spotify:playlist:1qmskWKKhG4KFtEHR4yHni', 's...         0.527  ...
# 277936  ['spotify:playlist:7JIp899qSdW6ngW8Abptjk', 's...         0.768  ...
# 277937  ['spotify:playlist:3elfQ0KvIu8TQpsZwTgJf6', 's...         0.779  ...
#
#         instrumentalness  liveness  valence    tempo  \
# 0               0.000794    0.7530    0.520  128.050
# 1               0.009530    0.3490    0.250  122.985
# 2               0.000008    0.2410    0.247  170.044
# 3               0.000088    0.0888    0.199   92.011
# 4               0.000001    0.0965    0.163  115.917
# ...                  ...       ...      ...      ...
# 277933          0.010800    0.0917    0.851  128.349
# 277934          0.000092    0.1110    0.415  193.513
# 277935          0.000000    0.1880    0.495  148.723
# 277936          0.000029    0.0970    0.962  118.773
# 277937          0.010700    0.0399    0.555  102.689
#
#                                              analysis_url  duration_ms  \
# 0       https://api.spotify.com/v1/audio-analysis/3v6s...     195000.0
# 1       https://api.spotify.com/v1/audio-analysis/7KCW...     194641.0
# 2       https://api.spotify.com/v1/audio-analysis/2CY9...     217573.0
# 3       https://api.spotify.com/v1/audio-analysis/11BP...     443478.0
# 4       https://api.spotify.com/v1/audio-analysis/3yUJ...     225862.0
# ...                                                   ...          ...
# 277933  https://api.spotify.com/v1/audio-analysis/6wLr...     276360.0
# 277934  https://api.spotify.com/v1/audio-analysis/5mYt...     284773.0
# 277935  https://api.spotify.com/v1/audio-analysis/7FwB...     241307.0
# 277936  https://api.spotify.com/v1/audio-analysis/2olV...     234333.0
# 277937  https://api.spotify.com/v1/audio-analysis/2VNf...     241920.0
#
#         time_signature  artists_popularities  \
# 0                  4.0                   [9]
# 1                  4.0              [68, 56]
# 2                  4.0                  [65]
# 3                  4.0                  [32]
# 4                  4.0              [30, 39]
# ...                ...                   ...
# 277933             4.0                  [70]
# 277934             4.0                  [63]
# 277935             4.0                  [76]
# 277936             4.0                  [65]
# 277937             4.0                  [70]
#
#                                            artists_genres  artists_followers
# 0                                                    [[]]              [765]
# 1       [['etherpop', 'pop', 'r&b'], ['chillstep', 'fu...  [1283665, 138396]
# 2       [['detroit hip hop', 'pop r&b', 'r&b', 'trap',...          [1544981]
# 3                         [['shimmer pop', 'shiver pop']]            [18241]
# 4                       [['indie poptimism'], ['la pop']]     [10105, 13775]
# ...                                                   ...                ...
# 277933  [['classic rock', 'folk', 'folk rock', 'mellow...          [2065865]
# 277934    [['german pop', 'german rock', 'new wave pop']]           [365584]
# 277935  [['classic rock', 'heartland rock', 'mellow go...          [5478543]
# 277936  [['album rock', 'classic rock', 'mellow gold',...          [1424479]
# 277937  [['art punk', 'art rock', 'dance rock', 'funk ...          [2106792]
#
# [277923 rows x 26 columns]

# %%
df2.
