# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\arinc\OneDrive\Desktop\csv's\TWTR\TWTR.csv")

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1  2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2  2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3  2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4  2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
#
#         Volume
# 0  117701670.0
# 1   27925307.0
# 2   16113941.0
# 3    6316755.0
# 4    8688325.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2264 non-null   object
#  1   Open       2259 non-null   float64
#  2   High       2259 non-null   float64
#  3   Low        2259 non-null   float64
#  4   Close      2259 non-null   float64
#  5   Adj Close  2259 non-null   float64
#  6   Volume     2259 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 123.9+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         5
# High         5
# Low          5
# Close        5
# Adj Close    5
# Volume       5
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
sns.distplot(df['Volume'])
# Out:
# <Axes: xlabel='Volume', ylabel='Density'>

# %%
sns.scatterplot(df['Volume'])
# Out:
# <Axes: ylabel='Volume'>

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.998860  0.998588  0.997414   0.997414 -0.015718
# High       0.998860  1.000000  0.998265  0.998731   0.998731 -0.001709
# Low        0.998588  0.998265  1.000000  0.998887   0.998887 -0.031352
# Close      0.997414  0.998731  0.998887  1.000000   1.000000 -0.019179
# Adj Close  0.997414  0.998731  0.998887  1.000000   1.000000 -0.019179
# Volume    -0.015718 -0.001709 -0.031352 -0.019179  -0.019179  1.000000

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2259.000000  2259.000000  2259.000000  2259.000000  2259.000000
# mean     36.020286    36.699881    35.339465    36.003625    36.003625
# std      14.118463    14.372057    13.828724    14.089989    14.089989
# min      13.950000    14.220000    13.725000    14.010000    14.010000
# 25%      25.550000    26.215001    24.912501    25.410000    25.410000
# 50%      35.419998    36.099998    34.820000    35.490002    35.490002
# 75%      44.205000    45.015000    43.327501    44.135000    44.135000
# max      78.360001    80.750000    76.050003    77.629997    77.629997
#
#              Volume
# count  2.259000e+03
# mean   2.175186e+07
# std    1.909988e+07
# min    0.000000e+00
# 25%    1.233530e+07
# 50%    1.691305e+07
# 75%    2.428082e+07
# max    2.692131e+08

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1  2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2  2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3  2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4  2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
#
#         Volume
# 0  117701670.0
# 1   27925307.0
# 2   16113941.0
# 3    6316755.0
# 4    8688325.0

# %%
df.drop(columns=['Date'], inplace = True)

# %%
X = df.drop(columns=['Volume'])
y = df['Volume']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=2,random_state=2)

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()

# %%
# scaler.fit(X_train)

# %%
# X_train_scaled = scaler.transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# %%
# scaler.mean_

# %%
# X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns)
# X_test_scaled = pd.DataFrame(X_test_scaled, columns = X_test.columns)

# %%
# np.round(X_train_scaled.describe(),1)

# %%
# from sklearn.linear_model import LogisticRegression

# %%
# lr = LogisticRegression()
# lr_scaled = LogisticRegression()

# %%
# lr.fit(X_train,y_train)
# lr_scaled.fit(X_train_scaled,y_train)

# %%
# y_pred = lr.predict(X_test)
# y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
# from sklearn.metrics import accuracy_score

# %%
# a = accuracy_score(y_test,y_pred)
# b = accuracy_score(y_test,y_pred_scaled)

# %%
df['Open'].plot(kind='kde'),df['Close'].plot(kind='kde')
# Out:
# (<Axes: ylabel='Density'>, <Axes: ylabel='Density'>)

# %%
df['High'].plot(kind='kde'),df['Low'].plot(kind='kde')
# Out:
# (<Axes: ylabel='Density'>, <Axes: ylabel='Density'>)

# %%
# df['Volume'].plot(kind='kde')

# %%
# # sample size = 50 -> 100 times
# # samples = []
# for i in range(100):
#     samples.append(df['Volume'].sample(50).values.tolist())

# %%
# samples = np.array(samples)

# %%
# sampling_mean = samples.mean(axis=1)

# %%
# sns.kdeplot(sampling_mean)

# %%
# a = sampling_mean.tolist()

# %%
y_train
# Out:
# 60      34001488.0
# 571     25796519.0
# 1055    21118485.0
# 259     18605048.0
# 627     21208443.0
#            ...
# 1071    67181217.0
# 433     29404090.0
# 674     19555747.0
# 1099    29561919.0
# 1608    24993383.0
# Name: Volume, Length: 2257, dtype: float64

# %%
X_train
# Out:
#            Open       High        Low      Close  Adj Close
# 60    67.160004  67.239998  64.800003  65.970001  65.970001
# 571   16.469999  17.600000  16.430000  17.459999  17.459999
# 1055  24.500000  24.520000  23.719999  24.040001  24.040001
# 259   40.689999  41.169998  39.950001  40.610001  40.610001
# 627   14.120000  14.400000  13.980000  14.400000  14.400000
# ...         ...        ...        ...        ...        ...
# 1071  30.370001  31.805000  29.680000  31.510000  31.510000
# 433   31.100000  31.830000  31.049999  31.469999  31.469999
# 674   18.020000  18.280001  17.910999  17.959999  17.959999
# 1099  31.770000  32.130001  31.174999  31.200001  31.200001
# 1608  25.790001  26.330601  24.400000  24.559999  24.559999
#
# [2257 rows x 5 columns]
